# %%
## Daily use
import argparse
import os, sys
import time
import datetime

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

## Pytorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.utils.data import Dataset as Dataset
from torch.utils.data import DataLoader as DataLoader
from tqdm import tqdm_notebook as tqdm
from PIL import Image

## test GPU
torch.cuda.is_available()
# Out:
# True

# %%
# load data
# change path to your own path.
path = "/home/jovyan/work/cifar10" 

train_x = np.load(os.path.join(path, "cifar10-batches-images-train.npy"))
train_y = np.load(os.path.join(path, "cifar10-batches-labels-train.npy"))
val_x = np.load(os.path.join(path, "cifar10-batches-images-val.npy"))
val_y = np.load(os.path.join(path, "cifar10-batches-labels-val.npy"))
test_x = np.load(os.path.join(path, "cifar10-batches-images-test.npy"))

# check mean and std
print(np.mean(train_x/255, axis=(0,1,2)))
print(np.std(train_x/255, axis=(0,1,2)))
# Out:
# [0.49205986 0.48287897 0.44727413]
# [0.24727619 0.2436752  0.26168613]

# %%
## transform
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.49205986, 0.48287897, 0.44727413], [0.24727619, 0.2436752, 0.26168613])
])

val_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.49205986, 0.48287897, 0.44727413], [0.24727619, 0.2436752, 0.26168613])
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.49205986, 0.48287897, 0.44727413], [0.24727619, 0.2436752, 0.26168613])
])

# %%
test_x.shape
# Out:
# (10000, 32, 32, 3)

# %%
## Hpyerparameters
TRAIN_BATCH_SIZE = 128
VAL_BATCH_SIZE = 100
INITIAL_LR = 0.03
MOMENTUM = 0.9
REG = 5e-4
EPOCHS = 100
CHECKPOINT_PATH = "./saved_model"

# %%
## Data Loader
class data(Dataset):
    def __init__(self, imgs, labels, transform):
        self.X = imgs
        self.y = labels
        self.transform = transform
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        img = self.X[index]
        img = Image.fromarray(img)
        if self.transform is not None:
            img = self.transform(img)
        return img, self.y[index]

train_data = data(train_x, train_y, transform = train_transform)
val_data = data(val_x, val_y, transform = train_transform)

# create empty label for test_data
empty = [-1] * test_x.shape[0]
test_data = data(test_x, empty, transform = test_transform)


train_loader = DataLoader(train_data, shuffle = True, batch_size = TRAIN_BATCH_SIZE, num_workers = 1)
val_loader = DataLoader(val_data, shuffle = True, batch_size = TRAIN_BATCH_SIZE, num_workers = 1)
test_loader = DataLoader(test_data, shuffle = False, batch_size = TRAIN_BATCH_SIZE, num_workers = 1)

# %%
for X,y in train_loader:
    print(X.shape)
    print(X.min())
    break
# Out:
# torch.Size([128, 3, 32, 32])
# tensor(-1.9899)

# %%
## create Model

## flatten layer
class flatten(nn.Module):
    def forward(self, x):
        return x.view(x.shape[0],-1)

# Create the neural network module: LeNet-5
class MyDNN(nn.Module):
    def __init__(self):
        super(MyDNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1)
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1)
        self.conv2_bn = nn.BatchNorm2d(32)
        self.pool12 = nn.MaxPool2d(2)
        self.dropout1 = nn.Dropout(0.2)
        
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.conv3_bn = nn.BatchNorm2d(64)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv4_bn = nn.BatchNorm2d(64)
        self.pool34 = nn.MaxPool2d(2)
        self.dropout2 = nn.Dropout(0.2)
        
        self.conv5 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv5_bn = nn.BatchNorm2d(128)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1)
        self.conv6_bn = nn.BatchNorm2d(128)
        self.pool56 = nn.MaxPool2d(2)
        self.dropout3 = nn.Dropout(0.2)
        
        
        self.flat  = flatten()
        
        self.fc1 = nn.Linear(4*4*128, 256)
        self.fc1_bn = nn.BatchNorm1d(256)
        self.dropout4 = nn.Dropout(0.5)
        self.fc2 = nn.Linear(256, 64)
        self.fc2_bn = nn.BatchNorm1d(64)
        self.dropout5 = nn.Dropout(0.5)
        self.fc3 = nn.Linear(64, 10)
        
        nn.init.xavier_normal_(self.conv1.weight)
        nn.init.xavier_normal_(self.conv2.weight)
        nn.init.xavier_normal_(self.conv3.weight)
        nn.init.xavier_normal_(self.conv4.weight)
        nn.init.xavier_normal_(self.conv5.weight)
        nn.init.xavier_normal_(self.conv6.weight)
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.xavier_normal_(self.fc3.weight)
        
        
        

    def forward(self, x):
        conv_pool12 = self.pool12(self.conv2_bn(F.relu(self.conv2(self.conv1_bn(F.relu(self.conv1(x)))))))
        conv_pool12 = self.dropout1(conv_pool12)
        conv_pool34 = self.pool34(self.conv4_bn(F.relu(self.conv4(self.conv3_bn(F.relu(self.conv3(conv_pool12)))))))
        conv_pool34 = self.dropout2(conv_pool34)
        conv_pool56 = self.pool56(self.conv6_bn(F.relu(self.conv6(self.conv5_bn(F.relu(self.conv5(conv_pool34)))))))
        conv_pool56 = self.dropout3(conv_pool56)
        
        return self.fc3(self.dropout5(self.fc2_bn(F.relu(self.fc2(self.dropout4(self.fc1_bn(F.relu(self.fc1(self.flat(conv_pool56))))))))))

# %%
net = MyDNN()
x = torch.zeros([128,3,32,32])
print(net(x).shape)
# Out:
# torch.Size([128, 10])

# %%
class sequential_mydnn(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_1 = nn.Sequential(
            nn.Conv2d(3, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Dropout(0.2)
        )
        
        self.conv_2 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Dropout(0.2)
        )
        
        self.conv_3 = nn.Sequential(
            nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.Conv2d(128, 128, kernel_size=3, stride=1, padding=1),
            nn.ReLU(),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Dropout(0.2)
        )
        
        self.fc = nn.Sequential(
            flatten(),
            nn.Linear(4*4*128, 256),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 64),
            nn.BatchNorm1d(64),
            nn.Dropout(0.5),
            nn.Linear(64,10)
        )
        
    def forward(self, x):
        return self.fc(self.conv_3(self.conv_2(self.conv_1(x))))

def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        m.weight.data.normal_(0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        m.weight.data.normal_(1.0, 0.02)
        m.bias.data.fill_(0)
    
net2 = sequential_mydnn()
x = torch.zeros([128,3,32,32])

net2.apply(weights_init) ## apply to print(net2.children)
# Out:
# <bound method Module.children of sequential_mydnn(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (fc): Sequential(
#     (0): flatten()
#     (1): Linear(in_features=2048, out_features=256, bias=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=64, out_features=10, bias=True)
#   )
# )>
# sequential_mydnn(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (fc): Sequential(
#     (0): flatten()
#     (1): Linear(in_features=2048, out_features=256, bias=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
print(net2)
# Out:
# sequential_mydnn(
#   (conv_1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (conv_3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Dropout(p=0.2, inplace=False)
#   )
#   (fc): Sequential(
#     (0): flatten()
#     (1): Linear(in_features=2048, out_features=256, bias=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=256, out_features=64, bias=True)
#     (5): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=64, out_features=10, bias=True)
#   )
# )

# %%
# Specify the device for computation
device = 'cuda' if torch.cuda.is_available() else 'cpu'
net = MyDNN()
net = net.to(device)
if device =='cuda':
    print("Train on GPU...")
else:
    print("Train on CPU...")
# Out:
# Train on GPU...

# %%
criterion = nn.CrossEntropyLoss()
# Add optimizer
optimizer = optim.SGD(net.parameters(), lr=INITIAL_LR, momentum=MOMENTUM)

# %%
TRAIN_FROM_SCRATCH = False
# Code for loading checkpoint and recover epoch id.
CKPT_PATH = "./saved_model/model.h5"
def get_checkpoint(ckpt_path):
    try:
        ckpt = torch.load(ckpt_path)
    except Exception as e:
        print(e)
        return None
    return ckpt

ckpt = get_checkpoint(CKPT_PATH)
if ckpt is None or TRAIN_FROM_SCRATCH:
    if not TRAIN_FROM_SCRATCH:
        print("Checkpoint not found.")
    print("Training from scratch ...")
    start_epoch = 0
    current_learning_rate = INITIAL_LR
else:
    print("Successfully loaded checkpoint: %s" %CKPT_PATH)
    net.load_state_dict(ckpt['net'])
    start_epoch = ckpt['epoch'] + 1
    current_learning_rate = ckpt['lr']
    print("Starting from epoch %d " %start_epoch)

print("Starting from learning rate %f:" %current_learning_rate)
# Out:
# Successfully loaded checkpoint: ./saved_model/model.h5
# Starting from epoch 144
# Starting from learning rate 0.000786:

# %%
global_step = 0
best_val_acc = 0

train_acc_recorder = []
train_loss_recorder = []
val_acc_recorder = []
val_loss_recorder = []



EPOCHS = 150

for i in range(start_epoch, EPOCHS):
    print(datetime.datetime.now())

    net.train()
    print("Epoch %d:" %i)

    total_examples = 0
    correct_examples = 0

    train_loss = 0
    train_acc = 0

    print(len(train_loader))
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs = inputs.to(device)
        targets = targets.to(device)
        
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, targets)
        for param in net.parameters():
            loss += REG * (param**2).sum()
        loss.backward()
        optimizer.step()
        _, predicted = torch.max(outputs, 1)
        total_examples += len(predicted)
        correct_examples += (predicted==targets).sum().item()
        train_loss += loss

        global_step += 1
        if global_step % 100 == 0:
            avg_loss = train_loss / (batch_idx + 1)
        pass
    avg_acc = correct_examples / total_examples
    print("Training loss: %.4f, Training accuracy: %.4f" %(avg_loss, avg_acc))
    
    train_acc_recorder.append(avg_acc)
    train_loss_recorder.append(avg_loss)
    
    print(datetime.datetime.now())
    print("Validation...")
    total_examples = 0
    correct_examples = 0
    
    net.eval()

    val_loss = 0
    val_acc = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(val_loader):
            inputs = inputs.to(device)
            targets = targets.to(device)
            optimizer.zero_grad()
            outputs = net(inputs)
            loss = criterion(outputs, targets)
            _, predicted = outputs.max(1)
            total_examples += len(predicted)
            correct_examples += (predicted==targets).sum().item()
            val_loss += loss

    avg_loss = val_loss / len(val_loader)
    avg_acc = correct_examples / total_examples
    print("Validation loss: %.4f, Validation accuracy: %.4f" % (avg_loss, avg_acc))
    
    val_acc_recorder.append(avg_acc)
    val_loss_recorder.append(avg_loss)
        

    DECAY_EPOCHS = 2
    DECAY = 0.95
    if i % DECAY_EPOCHS == 0 and i != 0:
        current_learning_rate = current_learning_rate*DECAY
        for param_group in optimizer.param_groups:
            param_group['lr'] = current_learning_rate
            # Assign the learning rate parameter
            
        print("Current learning rate has decayed to %f" %current_learning_rate)
    
    # Save for checkpoint
    if avg_acc > best_val_acc:
        best_val_acc = avg_acc
        if not os.path.exists(CHECKPOINT_PATH):
            os.makedirs(CHECKPOINT_PATH)
        print("Saving ...")
        state = {'net': net.state_dict(),
                 'epoch': i,
                 'lr': current_learning_rate}
        torch.save(state, os.path.join(CHECKPOINT_PATH, 'model.h5'))

print("Optimization finished.")
# Out:
# 2019-09-19 01:05:11.571606
# Epoch 0:
# 352
# Training loss: 2.9043, Training accuracy: 0.3138
# 2019-09-19 01:05:35.345976
# Validation...
# Validation loss: 1.5760, Validation accuracy: 0.4202
# Saving ...
# 2019-09-19 01:05:37.020147
# Epoch 1:
# 352
# Training loss: 2.3686, Training accuracy: 0.4316
# 2019-09-19 01:05:54.374569
# Validation...
# Validation loss: 1.3560, Validation accuracy: 0.5004
# Saving ...
# 2019-09-19 01:05:56.071644
# Epoch 2:
# 352
# Training loss: 2.0786, Training accuracy: 0.5102
# 2019-09-19 01:06:13.760325
# Validation...
# Validation loss: 1.1811, Validation accuracy: 0.5718
# Current learning rate has decayed to 0.028500
# Saving ...
# 2019-09-19 01:06:15.457223
# Epoch 3:
# 352
# Training loss: 1.8096, Training accuracy: 0.5740
# 2019-09-19 01:06:32.724504
# Validation...
# Validation loss: 1.0323, Validation accuracy: 0.6292
# Saving ...
# 2019-09-19 01:06:34.432360
# Epoch 4:
# 352
# Training loss: 1.6069, Training accuracy: 0.6289
# 2019-09-19 01:06:52.173363
# Validation...
# Validation loss: 0.8785, Validation accuracy: 0.6890
# Current learning rate has decayed to 0.027075
# Saving ...
# 2019-09-19 01:06:53.787004
# Epoch 5:
# 352
# Training loss: 1.4544, Training accuracy: 0.6663
# 2019-09-19 01:07:12.246725
# Validation...
# Validation loss: 0.8804, Validation accuracy: 0.6900
# Saving ...
# 2019-09-19 01:07:13.951462
# Epoch 6:
# 352
# Training loss: 1.3424, Training accuracy: 0.6981
# 2019-09-19 01:07:31.956460
# Validation...
# Validation loss: 0.7970, Validation accuracy: 0.7202
# Current learning rate has decayed to 0.025721
# Saving ...
# 2019-09-19 01:07:33.661814
# Epoch 7:
# 352
# Training loss: 1.2466, Training accuracy: 0.7215
# 2019-09-19 01:07:51.240983
# Validation...
# Validation loss: 0.7389, Validation accuracy: 0.7468
# Saving ...
# 2019-09-19 01:07:52.874976
# Epoch 8:
# 352
# Training loss: 1.1953, Training accuracy: 0.7338
# 2019-09-19 01:08:11.304089
# Validation...
# Validation loss: 0.7160, Validation accuracy: 0.7512
# Current learning rate has decayed to 0.024435
# Saving ...
# 2019-09-19 01:08:13.059402
# Epoch 9:
# 352
# Training loss: 1.1292, Training accuracy: 0.7503
# 2019-09-19 01:08:30.582917
# Validation...
# Validation loss: 0.6995, Validation accuracy: 0.7614
# Saving ...
# 2019-09-19 01:08:32.282809
# Epoch 10:
# 352
# Training loss: 1.0978, Training accuracy: 0.7576
# 2019-09-19 01:08:49.970904
# Validation...
# Validation loss: 0.6271, Validation accuracy: 0.7800
# Current learning rate has decayed to 0.023213
# Saving ...
# 2019-09-19 01:08:51.637481
# Epoch 11:
# 352
# Training loss: 1.0485, Training accuracy: 0.7687
# 2019-09-19 01:09:10.335233
# Validation...
# Validation loss: 0.6135, Validation accuracy: 0.7874
# Saving ...
# 2019-09-19 01:09:12.020873
# Epoch 12:
# 352
# Training loss: 1.0291, Training accuracy: 0.7732
# 2019-09-19 01:09:30.178750
# Validation...
# Validation loss: 0.6061, Validation accuracy: 0.7860
# Current learning rate has decayed to 0.022053
# 2019-09-19 01:09:31.780529
# Epoch 13:
# 352
# Training loss: 0.9996, Training accuracy: 0.7826
# 2019-09-19 01:09:49.754158
# Validation...
# Validation loss: 0.6229, Validation accuracy: 0.7880
# Saving ...
# 2019-09-19 01:09:51.486513
# Epoch 14:
# 352
# Training loss: 0.9686, Training accuracy: 0.7868
# 2019-09-19 01:10:09.517897
# Validation...
# Validation loss: 0.5670, Validation accuracy: 0.8040
# Current learning rate has decayed to 0.020950
# Saving ...
# 2019-09-19 01:10:11.247563
# Epoch 15:
# 352
# Training loss: 0.9536, Training accuracy: 0.7941
# 2019-09-19 01:10:28.984929
# Validation...
# Validation loss: 0.6036, Validation accuracy: 0.7942
# 2019-09-19 01:10:30.780741
# Epoch 16:
# 352
# Training loss: 0.9415, Training accuracy: 0.7926
# 2019-09-19 01:10:48.207769
# Validation...
# Validation loss: 0.5587, Validation accuracy: 0.8160
# Current learning rate has decayed to 0.019903
# Saving ...
# 2019-09-19 01:10:49.872124
# Epoch 17:
# 352
# Training loss: 0.9221, Training accuracy: 0.8027
# 2019-09-19 01:11:07.431288
# Validation...
# Validation loss: 0.5577, Validation accuracy: 0.8172
# Saving ...
# 2019-09-19 01:11:09.102377
# Epoch 18:
# 352
# Training loss: 0.9141, Training accuracy: 0.7999
# 2019-09-19 01:11:27.161313
# Validation...
# Validation loss: 0.5696, Validation accuracy: 0.8046
# Current learning rate has decayed to 0.018907
# 2019-09-19 01:11:28.775378
# Epoch 19:
# 352
# Training loss: 0.8975, Training accuracy: 0.8091
# 2019-09-19 01:11:46.297279
# Validation...
# Validation loss: 0.5239, Validation accuracy: 0.8252
# Saving ...
# 2019-09-19 01:11:48.043887
# Epoch 20:
# 352
# Training loss: 0.8858, Training accuracy: 0.8124
# 2019-09-19 01:12:05.317645
# Validation...
# Validation loss: 0.5484, Validation accuracy: 0.8150
# Current learning rate has decayed to 0.017962
# 2019-09-19 01:12:06.958437
# Epoch 21:
# 352
# Training loss: 0.8712, Training accuracy: 0.8144
# 2019-09-19 01:12:25.655339
# Validation...
# Validation loss: 0.4991, Validation accuracy: 0.8296
# Saving ...
# 2019-09-19 01:12:27.473112
# Epoch 22:
# 352
# Training loss: 0.8644, Training accuracy: 0.8166
# 2019-09-19 01:12:44.921841
# Validation...
# Validation loss: 0.5533, Validation accuracy: 0.8180
# Current learning rate has decayed to 0.017064
# 2019-09-19 01:12:46.639053
# Epoch 23:
# 352
# Training loss: 0.8502, Training accuracy: 0.8227
# 2019-09-19 01:13:04.300656
# Validation...
# Validation loss: 0.5074, Validation accuracy: 0.8280
# 2019-09-19 01:13:05.961357
# Epoch 24:
# 352
# Training loss: 0.8436, Training accuracy: 0.8226
# 2019-09-19 01:13:23.975951
# Validation...
# Validation loss: 0.5087, Validation accuracy: 0.8306
# Current learning rate has decayed to 0.016211
# Saving ...
# 2019-09-19 01:13:25.717755
# Epoch 25:
# 352
# Training loss: 0.8317, Training accuracy: 0.8261
# 2019-09-19 01:13:43.242311
# Validation...
# Validation loss: 0.4806, Validation accuracy: 0.8424
# Saving ...
# 2019-09-19 01:13:44.950237
# Epoch 26:
# 352
# Training loss: 0.8236, Training accuracy: 0.8268
# 2019-09-19 01:14:02.494117
# Validation...
# Validation loss: 0.4891, Validation accuracy: 0.8366
# Current learning rate has decayed to 0.015400
# 2019-09-19 01:14:04.248652
# Epoch 27:
# 352
# Training loss: 0.8112, Training accuracy: 0.8298
# 2019-09-19 01:14:22.341222
# Validation...
# Validation loss: 0.4912, Validation accuracy: 0.8318
# 2019-09-19 01:14:23.995388
# Epoch 28:
# 352
# Training loss: 0.8064, Training accuracy: 0.8332
# 2019-09-19 01:14:41.707154
# Validation...
# Validation loss: 0.4734, Validation accuracy: 0.8320
# Current learning rate has decayed to 0.014630
# 2019-09-19 01:14:43.428203
# Epoch 29:
# 352
# Training loss: 0.7941, Training accuracy: 0.8358
# 2019-09-19 01:15:01.551079
# Validation...
# Validation loss: 0.4773, Validation accuracy: 0.8368
# 2019-09-19 01:15:03.214319
# Epoch 30:
# 352
# Training loss: 0.7999, Training accuracy: 0.8328
# 2019-09-19 01:15:21.606875
# Validation...
# Validation loss: 0.4432, Validation accuracy: 0.8504
# Current learning rate has decayed to 0.013899
# Saving ...
# 2019-09-19 01:15:23.265144
# Epoch 31:
# 352
# Training loss: 0.7828, Training accuracy: 0.8396
# 2019-09-19 01:15:41.087380
# Validation...
# Validation loss: 0.4863, Validation accuracy: 0.8314
# 2019-09-19 01:15:42.768512
# Epoch 32:
# 352
# Training loss: 0.7807, Training accuracy: 0.8381
# 2019-09-19 01:16:01.402469
# Validation...
# Validation loss: 0.4928, Validation accuracy: 0.8344
# Current learning rate has decayed to 0.013204
# 2019-09-19 01:16:03.056175
# Epoch 33:
# 352
# Training loss: 0.7689, Training accuracy: 0.8406
# 2019-09-19 01:16:21.031001
# Validation...
# Validation loss: 0.4723, Validation accuracy: 0.8354
# 2019-09-19 01:16:23.166369
# Epoch 34:
# 352
# Training loss: 0.7618, Training accuracy: 0.8446
# 2019-09-19 01:16:40.746656
# Validation...
# Validation loss: 0.4469, Validation accuracy: 0.8480
# Current learning rate has decayed to 0.012544
# 2019-09-19 01:16:42.446832
# Epoch 35:
# 352
# Training loss: 0.7559, Training accuracy: 0.8463
# 2019-09-19 01:16:59.794212
# Validation...
# Validation loss: 0.4563, Validation accuracy: 0.8508
# Saving ...
# 2019-09-19 01:17:01.491813
# Epoch 36:
# 352
# Training loss: 0.7558, Training accuracy: 0.8455
# 2019-09-19 01:17:19.240118
# Validation...
# Validation loss: 0.4658, Validation accuracy: 0.8434
# Current learning rate has decayed to 0.011916
# 2019-09-19 01:17:20.887071
# Epoch 37:
# 352
# Training loss: 0.7434, Training accuracy: 0.8500
# 2019-09-19 01:17:38.832941
# Validation...
# Validation loss: 0.4518, Validation accuracy: 0.8444
# 2019-09-19 01:17:40.543169
# Epoch 38:
# 352
# Training loss: 0.7309, Training accuracy: 0.8517
# 2019-09-19 01:17:57.818411
# Validation...
# Validation loss: 0.4513, Validation accuracy: 0.8488
# Current learning rate has decayed to 0.011321
# 2019-09-19 01:17:59.463298
# Epoch 39:
# 352
# Training loss: 0.7251, Training accuracy: 0.8525
# 2019-09-19 01:18:16.939221
# Validation...
# Validation loss: 0.4392, Validation accuracy: 0.8496
# 2019-09-19 01:18:18.584642
# Epoch 40:
# 352
# Training loss: 0.7204, Training accuracy: 0.8561
# 2019-09-19 01:18:35.623696
# Validation...
# Validation loss: 0.4397, Validation accuracy: 0.8512
# Current learning rate has decayed to 0.010755
# Saving ...
# 2019-09-19 01:18:37.347272
# Epoch 41:
# 352
# Training loss: 0.7087, Training accuracy: 0.8577
# 2019-09-19 01:18:55.079392
# Validation...
# Validation loss: 0.4236, Validation accuracy: 0.8534
# Saving ...
# 2019-09-19 01:18:56.786606
# Epoch 42:
# 352
# Training loss: 0.7098, Training accuracy: 0.8578
# 2019-09-19 01:19:13.903702
# Validation...
# Validation loss: 0.4085, Validation accuracy: 0.8634
# Current learning rate has decayed to 0.010217
# Saving ...
# 2019-09-19 01:19:15.922177
# Epoch 43:
# 352
# Training loss: 0.6921, Training accuracy: 0.8630
# 2019-09-19 01:19:33.499785
# Validation...
# Validation loss: 0.4170, Validation accuracy: 0.8572
# 2019-09-19 01:19:35.171403
# Epoch 44:
# 352
# Training loss: 0.6943, Training accuracy: 0.8611
# 2019-09-19 01:19:53.063781
# Validation...
# Validation loss: 0.4062, Validation accuracy: 0.8570
# Current learning rate has decayed to 0.009706
# 2019-09-19 01:19:54.785601
# Epoch 45:
# 352
# Training loss: 0.6852, Training accuracy: 0.8634
# 2019-09-19 01:20:12.850401
# Validation...
# Validation loss: 0.4291, Validation accuracy: 0.8560
# 2019-09-19 01:20:14.524212
# Epoch 46:
# 352
# Training loss: 0.6838, Training accuracy: 0.8647
# 2019-09-19 01:20:32.103836
# Validation...
# Validation loss: 0.4328, Validation accuracy: 0.8510
# Current learning rate has decayed to 0.009221
# 2019-09-19 01:20:33.931749
# Epoch 47:
# 352
# Training loss: 0.6767, Training accuracy: 0.8629
# 2019-09-19 01:20:51.903858
# Validation...
# Validation loss: 0.4229, Validation accuracy: 0.8600
# 2019-09-19 01:20:53.559368
# Epoch 48:
# 352
# Training loss: 0.6772, Training accuracy: 0.8646
# 2019-09-19 01:21:11.065442
# Validation...
# Validation loss: 0.4077, Validation accuracy: 0.8616
# Current learning rate has decayed to 0.008760
# 2019-09-19 01:21:12.786985
# Epoch 49:
# 352
# Training loss: 0.6695, Training accuracy: 0.8668
# 2019-09-19 01:21:31.162121
# Validation...
# Validation loss: 0.3809, Validation accuracy: 0.8722
# Saving ...
# 2019-09-19 01:21:32.955330
# Epoch 50:
# 352
# Training loss: 0.6671, Training accuracy: 0.8674
# 2019-09-19 01:21:50.543257
# Validation...
# Validation loss: 0.4091, Validation accuracy: 0.8640
# Current learning rate has decayed to 0.008322
# 2019-09-19 01:21:52.272767
# Epoch 51:
# 352
# Training loss: 0.6564, Training accuracy: 0.8704
# 2019-09-19 01:22:09.640220
# Validation...
# Validation loss: 0.3916, Validation accuracy: 0.8628
# 2019-09-19 01:22:11.382930
# Epoch 52:
# 352
# Training loss: 0.6471, Training accuracy: 0.8728
# 2019-09-19 01:22:28.700657
# Validation...
# Validation loss: 0.4050, Validation accuracy: 0.8634
# Current learning rate has decayed to 0.007906
# 2019-09-19 01:22:30.435886
# Epoch 53:
# 352
# Training loss: 0.6431, Training accuracy: 0.8732
# 2019-09-19 01:22:47.808332
# Validation...
# Validation loss: 0.3916, Validation accuracy: 0.8702
# 2019-09-19 01:22:49.496709
# Epoch 54:
# 352
# Training loss: 0.6412, Training accuracy: 0.8729
# 2019-09-19 01:23:07.409306
# Validation...
# Validation loss: 0.4123, Validation accuracy: 0.8610
# Current learning rate has decayed to 0.007510
# 2019-09-19 01:23:09.140449
# Epoch 55:
# 352
# Training loss: 0.6317, Training accuracy: 0.8745
# 2019-09-19 01:23:25.980375
# Validation...
# Validation loss: 0.3913, Validation accuracy: 0.8692
# 2019-09-19 01:23:27.656571
# Epoch 56:
# 352
# Training loss: 0.6272, Training accuracy: 0.8771
# 2019-09-19 01:23:45.320246
# Validation...
# Validation loss: 0.3894, Validation accuracy: 0.8698
# Current learning rate has decayed to 0.007135
# 2019-09-19 01:23:47.076026
# Epoch 57:
# 352
# Training loss: 0.6203, Training accuracy: 0.8792
# 2019-09-19 01:24:04.911301
# Validation...
# Validation loss: 0.3818, Validation accuracy: 0.8736
# Saving ...
# 2019-09-19 01:24:06.626741
# Epoch 58:
# 352
# Training loss: 0.6187, Training accuracy: 0.8791
# 2019-09-19 01:24:24.260712
# Validation...
# Validation loss: 0.3958, Validation accuracy: 0.8680
# Current learning rate has decayed to 0.006778
# 2019-09-19 01:24:26.039441
# Epoch 59:
# 352
# Training loss: 0.6135, Training accuracy: 0.8812
# 2019-09-19 01:24:44.575216
# Validation...
# Validation loss: 0.3806, Validation accuracy: 0.8724
# 2019-09-19 01:24:46.320343
# Epoch 60:
# 352
# Training loss: 0.6089, Training accuracy: 0.8812
# 2019-09-19 01:25:03.900326
# Validation...
# Validation loss: 0.3981, Validation accuracy: 0.8766
# Current learning rate has decayed to 0.006439
# Saving ...
# 2019-09-19 01:25:05.619396
# Epoch 61:
# 352
# Training loss: 0.6030, Training accuracy: 0.8827
# 2019-09-19 01:25:23.881600
# Validation...
# Validation loss: 0.3771, Validation accuracy: 0.8742
# 2019-09-19 01:25:25.610183
# Epoch 62:
# 352
# Training loss: 0.5982, Training accuracy: 0.8829
# 2019-09-19 01:25:43.560254
# Validation...
# Validation loss: 0.3693, Validation accuracy: 0.8812
# Current learning rate has decayed to 0.006117
# Saving ...
# 2019-09-19 01:25:45.329101
# Epoch 63:
# 352
# Training loss: 0.5931, Training accuracy: 0.8840
# 2019-09-19 01:26:03.145115
# Validation...
# Validation loss: 0.3929, Validation accuracy: 0.8704
# 2019-09-19 01:26:04.880191
# Epoch 64:
# 352
# Training loss: 0.5934, Training accuracy: 0.8847
# 2019-09-19 01:26:23.357176
# Validation...
# Validation loss: 0.4082, Validation accuracy: 0.8642
# Current learning rate has decayed to 0.005811
# 2019-09-19 01:26:25.037997
# Epoch 65:
# 352
# Training loss: 0.5832, Training accuracy: 0.8866
# 2019-09-19 01:26:43.213329
# Validation...
# Validation loss: 0.3936, Validation accuracy: 0.8786
# 2019-09-19 01:26:45.016077
# Epoch 66:
# 352
# Training loss: 0.5839, Training accuracy: 0.8885
# 2019-09-19 01:27:03.289780
# Validation...
# Validation loss: 0.3816, Validation accuracy: 0.8756
# Current learning rate has decayed to 0.005521
# 2019-09-19 01:27:05.106583
# Epoch 67:
# 352
# Training loss: 0.5744, Training accuracy: 0.8898
# 2019-09-19 01:27:23.826985
# Validation...
# Validation loss: 0.3725, Validation accuracy: 0.8832
# Saving ...
# 2019-09-19 01:27:25.632209
# Epoch 68:
# 352
# Training loss: 0.5703, Training accuracy: 0.8909
# 2019-09-19 01:27:44.521610
# Validation...
# Validation loss: 0.3606, Validation accuracy: 0.8802
# Current learning rate has decayed to 0.005245
# 2019-09-19 01:27:46.211599
# Epoch 69:
# 352
# Training loss: 0.5707, Training accuracy: 0.8892
# 2019-09-19 01:28:04.829352
# Validation...
# Validation loss: 0.3623, Validation accuracy: 0.8740
# 2019-09-19 01:28:06.645184
# Epoch 70:
# 352
# Training loss: 0.5622, Training accuracy: 0.8896
# 2019-09-19 01:28:25.386385
# Validation...
# Validation loss: 0.3677, Validation accuracy: 0.8790
# Current learning rate has decayed to 0.004983
# 2019-09-19 01:28:27.094045
# Epoch 71:
# 352
# Training loss: 0.5561, Training accuracy: 0.8938
# 2019-09-19 01:28:46.066128
# Validation...
# Validation loss: 0.3615, Validation accuracy: 0.8870
# Saving ...
# 2019-09-19 01:28:47.795018
# Epoch 72:
# 352
# Training loss: 0.5507, Training accuracy: 0.8926
# 2019-09-19 01:29:06.182124
# Validation...
# Validation loss: 0.3656, Validation accuracy: 0.8800
# Current learning rate has decayed to 0.004733
# 2019-09-19 01:29:07.884238
# Epoch 73:
# 352
# Training loss: 0.5451, Training accuracy: 0.8957
# 2019-09-19 01:29:26.390062
# Validation...
# Validation loss: 0.3600, Validation accuracy: 0.8778
# 2019-09-19 01:29:28.096363
# Epoch 74:
# 352
# Training loss: 0.5529, Training accuracy: 0.8931
# 2019-09-19 01:29:45.654581
# Validation...
# Validation loss: 0.3732, Validation accuracy: 0.8778
# Current learning rate has decayed to 0.004497
# 2019-09-19 01:29:47.364945
# Epoch 75:
# 352
# Training loss: 0.5364, Training accuracy: 0.9000
# 2019-09-19 01:30:05.918197
# Validation...
# Validation loss: 0.3547, Validation accuracy: 0.8862
# 2019-09-19 01:30:07.596191
# Epoch 76:
# 352
# Training loss: 0.5333, Training accuracy: 0.8991
# 2019-09-19 01:30:25.590161
# Validation...
# Validation loss: 0.3819, Validation accuracy: 0.8852
# Current learning rate has decayed to 0.004272
# 2019-09-19 01:30:27.278447
# Epoch 77:
# 352
# Training loss: 0.5320, Training accuracy: 0.9014
# 2019-09-19 01:30:45.561832
# Validation...
# Validation loss: 0.3431, Validation accuracy: 0.8862
# 2019-09-19 01:30:47.314618
# Epoch 78:
# 352
# Training loss: 0.5266, Training accuracy: 0.9012
# 2019-09-19 01:31:05.846499
# Validation...
# Validation loss: 0.3410, Validation accuracy: 0.8866
# Current learning rate has decayed to 0.004058
# 2019-09-19 01:31:07.573892
# Epoch 79:
# 352
# Training loss: 0.5274, Training accuracy: 0.8984
# 2019-09-19 01:31:25.925439
# Validation...
# Validation loss: 0.3505, Validation accuracy: 0.8824
# 2019-09-19 01:31:27.653953
# Epoch 80:
# 352
# Training loss: 0.5204, Training accuracy: 0.9030
# 2019-09-19 01:31:45.823931
# Validation...
# Validation loss: 0.3294, Validation accuracy: 0.8932
# Current learning rate has decayed to 0.003855
# Saving ...
# 2019-09-19 01:31:47.659848
# Epoch 81:
# 352
# Training loss: 0.5164, Training accuracy: 0.9025
# 2019-09-19 01:32:05.918793
# Validation...
# Validation loss: 0.3381, Validation accuracy: 0.8920
# 2019-09-19 01:32:07.639254
# Epoch 82:
# 352
# Training loss: 0.5152, Training accuracy: 0.9036
# 2019-09-19 01:32:25.018126
# Validation...
# Validation loss: 0.3384, Validation accuracy: 0.8882
# Current learning rate has decayed to 0.003663
# 2019-09-19 01:32:26.782639
# Epoch 83:
# 352
# Training loss: 0.5042, Training accuracy: 0.9070
# 2019-09-19 01:32:44.934315
# Validation...
# Validation loss: 0.3356, Validation accuracy: 0.8872
# 2019-09-19 01:32:46.670426
# Epoch 84:
# 352
# Training loss: 0.5054, Training accuracy: 0.9060
# 2019-09-19 01:33:04.291607
# Validation...
# Validation loss: 0.3691, Validation accuracy: 0.8844
# Current learning rate has decayed to 0.003479
# 2019-09-19 01:33:05.987997
# Epoch 85:
# 352
# Training loss: 0.4967, Training accuracy: 0.9067
# 2019-09-19 01:33:24.307031
# Validation...
# Validation loss: 0.3373, Validation accuracy: 0.8940
# Saving ...
# 2019-09-19 01:33:26.069632
# Epoch 86:
# 352
# Training loss: 0.4994, Training accuracy: 0.9064
# 2019-09-19 01:33:44.607121
# Validation...
# Validation loss: 0.3364, Validation accuracy: 0.8862
# Current learning rate has decayed to 0.003305
# 2019-09-19 01:33:46.404954
# Epoch 87:
# 352
# Training loss: 0.4922, Training accuracy: 0.9092
# 2019-09-19 01:34:05.187477
# Validation...
# Validation loss: 0.3165, Validation accuracy: 0.8942
# Saving ...
# 2019-09-19 01:34:07.083291
# Epoch 88:
# 352
# Training loss: 0.4851, Training accuracy: 0.9104
# 2019-09-19 01:34:25.282856
# Validation...
# Validation loss: 0.3612, Validation accuracy: 0.8860
# Current learning rate has decayed to 0.003140
# 2019-09-19 01:34:27.088683
# Epoch 89:
# 352
# Training loss: 0.4816, Training accuracy: 0.9128
# 2019-09-19 01:34:44.779027
# Validation...
# Validation loss: 0.3331, Validation accuracy: 0.8872
# 2019-09-19 01:34:46.614598
# Epoch 90:
# 352
# Training loss: 0.4889, Training accuracy: 0.9070
# 2019-09-19 01:35:04.859188
# Validation...
# Validation loss: 0.3449, Validation accuracy: 0.8864
# Current learning rate has decayed to 0.002983
# 2019-09-19 01:35:06.658028
# Epoch 91:
# 352
# Training loss: 0.4740, Training accuracy: 0.9136
# 2019-09-19 01:35:24.477725
# Validation...
# Validation loss: 0.3380, Validation accuracy: 0.8942
# 2019-09-19 01:35:26.290365
# Epoch 92:
# 352
# Training loss: 0.4762, Training accuracy: 0.9110
# 2019-09-19 01:35:43.923614
# Validation...
# Validation loss: 0.3309, Validation accuracy: 0.8928
# Current learning rate has decayed to 0.002834
# 2019-09-19 01:35:45.726687
# Epoch 93:
# 352
# Training loss: 0.4746, Training accuracy: 0.9122
# 2019-09-19 01:36:03.675715
# Validation...
# Validation loss: 0.3274, Validation accuracy: 0.8912
# 2019-09-19 01:36:05.696045
# Epoch 94:
# 352
# Training loss: 0.4667, Training accuracy: 0.9147
# 2019-09-19 01:36:23.447907
# Validation...
# Validation loss: 0.3489, Validation accuracy: 0.8860
# Current learning rate has decayed to 0.002692
# 2019-09-19 01:36:25.264944
# Epoch 95:
# 352
# Training loss: 0.4596, Training accuracy: 0.9167
# 2019-09-19 01:36:43.373540
# Validation...
# Validation loss: 0.3477, Validation accuracy: 0.8886
# 2019-09-19 01:36:45.124958
# Epoch 96:
# 352
# Training loss: 0.4661, Training accuracy: 0.9152
# 2019-09-19 01:37:03.240451
# Validation...
# Validation loss: 0.3247, Validation accuracy: 0.8932
# Current learning rate has decayed to 0.002558
# 2019-09-19 01:37:04.963973
# Epoch 97:
# 352
# Training loss: 0.4536, Training accuracy: 0.9172
# 2019-09-19 01:37:23.039429
# Validation...
# Validation loss: 0.3378, Validation accuracy: 0.8938
# 2019-09-19 01:37:24.912533
# Epoch 98:
# 352
# Training loss: 0.4545, Training accuracy: 0.9162
# 2019-09-19 01:37:43.191990
# Validation...
# Validation loss: 0.3394, Validation accuracy: 0.8876
# Current learning rate has decayed to 0.002430
# 2019-09-19 01:37:44.871474
# Epoch 99:
# 352
# Training loss: 0.4511, Training accuracy: 0.9170
# 2019-09-19 01:38:03.308177
# Validation...
# Validation loss: 0.3251, Validation accuracy: 0.8944
# Saving ...
# 2019-09-19 01:38:05.144920
# Epoch 100:
# 352
# Training loss: 0.4496, Training accuracy: 0.9185
# 2019-09-19 01:38:22.667121
# Validation...
# Validation loss: 0.3335, Validation accuracy: 0.8954
# Current learning rate has decayed to 0.002308
# Saving ...
# 2019-09-19 01:38:24.497444
# Epoch 101:
# 352
# Training loss: 0.4431, Training accuracy: 0.9205
# 2019-09-19 01:38:42.672348
# Validation...
# Validation loss: 0.3236, Validation accuracy: 0.8934
# 2019-09-19 01:38:44.484249
# Epoch 102:
# 352
# Training loss: 0.4388, Training accuracy: 0.9201
# 2019-09-19 01:39:02.040376
# Validation...
# Validation loss: 0.3351, Validation accuracy: 0.8946
# Current learning rate has decayed to 0.002193
# 2019-09-19 01:39:03.791146
# Epoch 103:
# 352
# Training loss: 0.4376, Training accuracy: 0.9197
# 2019-09-19 01:39:22.107256
# Validation...
# Validation loss: 0.3406, Validation accuracy: 0.8944
# 2019-09-19 01:39:23.860076
# Epoch 104:
# 352
# Training loss: 0.4311, Training accuracy: 0.9202
# 2019-09-19 01:39:41.512596
# Validation...
# Validation loss: 0.3388, Validation accuracy: 0.8950
# Current learning rate has decayed to 0.002083
# 2019-09-19 01:39:43.286779
# Epoch 105:
# 352
# Training loss: 0.4359, Training accuracy: 0.9204
# 2019-09-19 01:40:01.040676
# Validation...
# Validation loss: 0.3158, Validation accuracy: 0.8992
# Saving ...
# 2019-09-19 01:40:02.951621
# Epoch 106:
# 352
# Training loss: 0.4266, Training accuracy: 0.9232
# 2019-09-19 01:40:20.632897
# Validation...
# Validation loss: 0.3433, Validation accuracy: 0.8946
# Current learning rate has decayed to 0.001979
# 2019-09-19 01:40:22.372389
# Epoch 107:
# 352
# Training loss: 0.4329, Training accuracy: 0.9214
# 2019-09-19 01:40:40.830745
# Validation...
# Validation loss: 0.3112, Validation accuracy: 0.8976
# 2019-09-19 01:40:42.668840
# Epoch 108:
# 352
# Training loss: 0.4240, Training accuracy: 0.9248
# 2019-09-19 01:41:01.119998
# Validation...
# Validation loss: 0.3471, Validation accuracy: 0.8968
# Current learning rate has decayed to 0.001880
# 2019-09-19 01:41:03.176791
# Epoch 109:
# 352
# Training loss: 0.4211, Training accuracy: 0.9236
# 2019-09-19 01:41:20.576990
# Validation...
# Validation loss: 0.3110, Validation accuracy: 0.9024
# Saving ...
# 2019-09-19 01:41:22.338489
# Epoch 110:
# 352
# Training loss: 0.4161, Training accuracy: 0.9266
# 2019-09-19 01:41:40.217990
# Validation...
# Validation loss: 0.3148, Validation accuracy: 0.8986
# Current learning rate has decayed to 0.001786
# 2019-09-19 01:41:42.040829
# Epoch 111:
# 352
# Training loss: 0.4147, Training accuracy: 0.9271
# 2019-09-19 01:41:59.880870
# Validation...
# Validation loss: 0.3251, Validation accuracy: 0.8998
# 2019-09-19 01:42:01.743921
# Epoch 112:
# 352
# Training loss: 0.4069, Training accuracy: 0.9275
# 2019-09-19 01:42:19.660466
# Validation...
# Validation loss: 0.3138, Validation accuracy: 0.8990
# Current learning rate has decayed to 0.001697
# 2019-09-19 01:42:21.476135
# Epoch 113:
# 352
# Training loss: 0.4147, Training accuracy: 0.9260
# 2019-09-19 01:42:39.565143
# Validation...
# Validation loss: 0.3098, Validation accuracy: 0.9038
# Saving ...
# 2019-09-19 01:42:41.378789
# Epoch 114:
# 352
# Training loss: 0.4087, Training accuracy: 0.9280
# 2019-09-19 01:42:58.953595
# Validation...
# Validation loss: 0.3073, Validation accuracy: 0.9008
# Current learning rate has decayed to 0.001612
# 2019-09-19 01:43:00.737364
# Epoch 115:
# 352
# Training loss: 0.4088, Training accuracy: 0.9282
# 2019-09-19 01:43:17.997660
# Validation...
# Validation loss: 0.3147, Validation accuracy: 0.8964
# 2019-09-19 01:43:19.857766
# Epoch 116:
# 352
# Training loss: 0.3991, Training accuracy: 0.9302
# 2019-09-19 01:43:37.767432
# Validation...
# Validation loss: 0.3193, Validation accuracy: 0.9060
# Current learning rate has decayed to 0.001531
# Saving ...
# 2019-09-19 01:43:39.584571
# Epoch 117:
# 352
# Training loss: 0.4003, Training accuracy: 0.9314
# 2019-09-19 01:43:57.521461
# Validation...
# Validation loss: 0.3212, Validation accuracy: 0.8952
# 2019-09-19 01:43:59.242965
# Epoch 118:
# 352
# Training loss: 0.3990, Training accuracy: 0.9292
# 2019-09-19 01:44:17.317514
# Validation...
# Validation loss: 0.3157, Validation accuracy: 0.9038
# Current learning rate has decayed to 0.001455
# 2019-09-19 01:44:19.053847
# Epoch 119:
# 352
# Training loss: 0.3938, Training accuracy: 0.9320
# 2019-09-19 01:44:37.674941
# Validation...
# Validation loss: 0.3170, Validation accuracy: 0.9016
# 2019-09-19 01:44:39.525975
# Epoch 120:
# 352
# Training loss: 0.3918, Training accuracy: 0.9321
# 2019-09-19 01:44:58.201833
# Validation...
# Validation loss: 0.3039, Validation accuracy: 0.9018
# Current learning rate has decayed to 0.001382
# 2019-09-19 01:44:59.963533
# Epoch 121:
# 352
# Training loss: 0.3840, Training accuracy: 0.9339
# 2019-09-19 01:45:18.010916
# Validation...
# Validation loss: 0.3442, Validation accuracy: 0.8998
# 2019-09-19 01:45:19.809632
# Epoch 122:
# 352
# Training loss: 0.3884, Training accuracy: 0.9326
# 2019-09-19 01:45:38.161966
# Validation...
# Validation loss: 0.3194, Validation accuracy: 0.8986
# Current learning rate has decayed to 0.001313
# 2019-09-19 01:45:40.037792
# Epoch 123:
# 352
# Training loss: 0.3873, Training accuracy: 0.9337
# 2019-09-19 01:45:57.573177
# Validation...
# Validation loss: 0.3094, Validation accuracy: 0.9048
# 2019-09-19 01:45:59.450456
# Epoch 124:
# 352
# Training loss: 0.3846, Training accuracy: 0.9336
# 2019-09-19 01:46:17.950265
# Validation...
# Validation loss: 0.3239, Validation accuracy: 0.8990
# Current learning rate has decayed to 0.001247
# 2019-09-19 01:46:19.765772
# Epoch 125:
# 352
# Training loss: 0.3820, Training accuracy: 0.9339
# 2019-09-19 01:46:38.053810
# Validation...
# Validation loss: 0.3208, Validation accuracy: 0.9000
# 2019-09-19 01:46:39.925407
# Epoch 126:
# 352
# Training loss: 0.3795, Training accuracy: 0.9346
# 2019-09-19 01:46:57.602565
# Validation...
# Validation loss: 0.3227, Validation accuracy: 0.9032
# Current learning rate has decayed to 0.001185
# 2019-09-19 01:46:59.415956
# Epoch 127:
# 352
# Training loss: 0.3730, Training accuracy: 0.9355
# 2019-09-19 01:47:17.116098
# Validation...
# Validation loss: 0.3165, Validation accuracy: 0.9046
# 2019-09-19 01:47:18.915105
# Epoch 128:
# 352
# Training loss: 0.3737, Training accuracy: 0.9365
# 2019-09-19 01:47:37.286390
# Validation...
# Validation loss: 0.3066, Validation accuracy: 0.9028
# Current learning rate has decayed to 0.001126
# 2019-09-19 01:47:39.091056
# Epoch 129:
# 352
# Training loss: 0.3773, Training accuracy: 0.9355
# 2019-09-19 01:47:56.974827
# Validation...
# Validation loss: 0.3188, Validation accuracy: 0.8992
# 2019-09-19 01:47:58.784650
# Epoch 130:
# 352
# Training loss: 0.3695, Training accuracy: 0.9368
# 2019-09-19 01:48:16.820094
# Validation...
# Validation loss: 0.3258, Validation accuracy: 0.9054
# Current learning rate has decayed to 0.001069
# 2019-09-19 01:48:18.550877
# Epoch 131:
# 352
# Training loss: 0.3637, Training accuracy: 0.9391
# 2019-09-19 01:48:36.759220
# Validation...
# Validation loss: 0.3370, Validation accuracy: 0.9018
# 2019-09-19 01:48:38.634875
# Epoch 132:
# 352
# Training loss: 0.3641, Training accuracy: 0.9382
# 2019-09-19 01:48:56.968423
# Validation...
# Validation loss: 0.3189, Validation accuracy: 0.9012
# Current learning rate has decayed to 0.001016
# 2019-09-19 01:48:58.782732
# Epoch 133:
# 352
# Training loss: 0.3618, Training accuracy: 0.9388
# 2019-09-19 01:49:16.407190
# Validation...
# Validation loss: 0.3254, Validation accuracy: 0.9008
# 2019-09-19 01:49:18.151868
# Epoch 134:
# 352
# Training loss: 0.3640, Training accuracy: 0.9385
# 2019-09-19 01:49:36.571017
# Validation...
# Validation loss: 0.3196, Validation accuracy: 0.9020
# Current learning rate has decayed to 0.000965
# 2019-09-19 01:49:38.449723
# Epoch 135:
# 352
# Training loss: 0.3554, Training accuracy: 0.9410
# 2019-09-19 01:49:56.566898
# Validation...
# Validation loss: 0.3078, Validation accuracy: 0.9024
# 2019-09-19 01:49:58.303062
# Epoch 136:
# 352
# Training loss: 0.3594, Training accuracy: 0.9399
# 2019-09-19 01:50:16.716718
# Validation...
# Validation loss: 0.3150, Validation accuracy: 0.9020
# Current learning rate has decayed to 0.000917
# 2019-09-19 01:50:18.485904
# Epoch 137:
# 352
# Training loss: 0.3532, Training accuracy: 0.9414
# 2019-09-19 01:50:36.738525
# Validation...
# Validation loss: 0.3203, Validation accuracy: 0.9018
# 2019-09-19 01:50:38.739185
# Epoch 138:
# 352
# Training loss: 0.3499, Training accuracy: 0.9424
# 2019-09-19 01:50:56.243318
# Validation...
# Validation loss: 0.3121, Validation accuracy: 0.9020
# Current learning rate has decayed to 0.000871
# 2019-09-19 01:50:58.071669
# Epoch 139:
# 352
# Training loss: 0.3516, Training accuracy: 0.9405
# 2019-09-19 01:51:15.827422
# Validation...
# Validation loss: 0.3232, Validation accuracy: 0.8988
# 2019-09-19 01:51:17.716671
# Epoch 140:
# 352
# Training loss: 0.3470, Training accuracy: 0.9418
# 2019-09-19 01:51:35.676877
# Validation...
# Validation loss: 0.3097, Validation accuracy: 0.9076
# Current learning rate has decayed to 0.000828
# Saving ...
# 2019-09-19 01:51:37.551690
# Epoch 141:
# 352
# Training loss: 0.3478, Training accuracy: 0.9415
# 2019-09-19 01:51:55.978480
# Validation...
# Validation loss: 0.3297, Validation accuracy: 0.9058
# 2019-09-19 01:51:57.792810
# Epoch 142:
# 352
# Training loss: 0.3487, Training accuracy: 0.9422
# 2019-09-19 01:52:16.283345
# Validation...
# Validation loss: 0.3183, Validation accuracy: 0.9026
# Current learning rate has decayed to 0.000786
# 2019-09-19 01:52:18.102476
# Epoch 143:
# 352
# Training loss: 0.3378, Training accuracy: 0.9462
# 2019-09-19 01:52:36.431749
# Validation...
# Validation loss: 0.3199, Validation accuracy: 0.9092
# Saving ...
# 2019-09-19 01:52:38.425792
# Epoch 144:
# 352
# Training loss: 0.3489, Training accuracy: 0.9429
# 2019-09-19 01:52:56.708334
# Validation...
# Validation loss: 0.3106, Validation accuracy: 0.9082
# Current learning rate has decayed to 0.000747
# 2019-09-19 01:52:58.643671
# Epoch 145:
# 352
# Training loss: 0.3393, Training accuracy: 0.9447
# 2019-09-19 01:53:16.663971
# Validation...
# Validation loss: 0.3130, Validation accuracy: 0.9038
# 2019-09-19 01:53:18.527970
# Epoch 146:
# 352
# Training loss: 0.3367, Training accuracy: 0.9452
# 2019-09-19 01:53:36.080313
# Validation...
# Validation loss: 0.3040, Validation accuracy: 0.9058
# Current learning rate has decayed to 0.000709
# 2019-09-19 01:53:37.867569
# Epoch 147:
# 352
# Training loss: 0.3392, Training accuracy: 0.9455
# 2019-09-19 01:53:56.183935
# Validation...
# Validation loss: 0.3241, Validation accuracy: 0.9026
# 2019-09-19 01:53:58.044378
# Epoch 148:
# 352
# Training loss: 0.3349, Training accuracy: 0.9458
# 2019-09-19 01:54:16.141441
# Validation...
# Validation loss: 0.3029, Validation accuracy: 0.9092
# Current learning rate has decayed to 0.000674
# 2019-09-19 01:54:18.080524
# Epoch 149:
# 352
# Training loss: 0.3340, Training accuracy: 0.9460
# 2019-09-19 01:54:36.026291
# Validation...
# Validation loss: 0.3296, Validation accuracy: 0.9062
# Optimization finished.

# %%
## load model
CKPT_PATH = "./saved_model/model.h5"
ckpt = get_checkpoint(CKPT_PATH)
net.load_state_dict(ckpt['net'])
start_epoch = ckpt['epoch'] + 1
current_learning_rate = ckpt['lr']

## predicted values
pred = np.zeros([10000,2])
pred[:,0] = np.arange(10000)

net.eval()
with torch.no_grad():
    for idx, (inputs, _) in enumerate(test_loader):
        inputs = inputs.to(device)
        optimizer.zero_grad()
        outputs = net(inputs)
        _, predicted = outputs.max(1)
        pred[idx*TRAIN_BATCH_SIZE:(idx*TRAIN_BATCH_SIZE+len(predicted)), 1] =predicted.cpu().data.numpy()
        
np.savetxt('pred_labels.csv', pred.astype(int), fmt = "%d", delimiter=',', header='Id,Category', comments='')
